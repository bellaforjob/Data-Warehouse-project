# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#load invoice 
data_invoice = pd.read_csv("Invoices.csv")
data_invoice.head()
# Out:
#            Order Id        Date           Meal Id        Company Id  \
# 0  839FKFW2LLX4LMBB  2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1  97OX39BGVMHODLJM  2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2  041ORQM5OIHTIU6L  2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3  YT796QI18WNGZ7ZJ  2014-12-04  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4  6YLROQT27B6HRF4E  2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
#
#                 Date of Meal                       Participants  Meal Price  \
# 0  2016-05-31 07:00:00+02:00                   ['David Bishop']         469
# 1  2018-10-01 20:00:00+02:00                   ['David Bishop']          22
# 2  2014-08-23 14:00:00+02:00                 ['Karen Stansell']         314
# 3  2014-04-07 21:00:00+02:00                   ['Addie Patino']         438
# 4  2015-07-27 14:00:00+02:00  ['Addie Patino' 'Susan Guerrero']         690
#
#   Type of Meal
# 0    Breakfast
# 1       Dinner
# 2        Lunch
# 3       Dinner
# 4        Lunch

# %%
data_invoice.dtypes
# Out:
# Order Id        object
# Date            object
# Meal Id         object
# Company Id      object
# Date of Meal    object
# Participants    object
# Meal Price       int64
# Type of Meal    object
# dtype: object

# %%
#convert the date to date type
data_invoice.Date = pd.to_datetime(data_invoice.Date)
print(data_invoice.Date)
# Out:
# 0       2016-05-27
# 1       2018-09-27
# 2       2014-08-24
# 3       2014-12-04
# 4       2015-07-28
#            ...
# 50012   2017-09-20
# 50013   2018-03-19
# 50014   2017-09-21
# 50015   2018-01-28
# 50016   2017-06-09
# Name: Date, Length: 50017, dtype: datetime64[ns]

# %%
#check if there is any null value
data_invoice.isnull()
# Out:
#        Order Id   Date  Meal Id  Company Id  Date of Meal  Participants  \
# 0         False  False    False       False         False         False
# 1         False  False    False       False         False         False
# 2         False  False    False       False         False         False
# 3         False  False    False       False         False         False
# 4         False  False    False       False         False         False
# ...         ...    ...      ...         ...           ...           ...
# 50012     False  False    False       False         False         False
# 50013     False  False    False       False         False         False
# 50014     False  False    False       False         False         False
# 50015     False  False    False       False         False         False
# 50016     False  False    False       False         False         False
#
#        Meal Price  Type of Meal
# 0           False         False
# 1           False         False
# ...

# %%
#save the date back
data_invoice.to_csv("invoices.csv", index = False)

# %%
#check it
pd.read_csv("Invoices.csv")
# Out:
#                Order Id        Date           Meal Id        Company Id  \
# 0      839FKFW2LLX4LMBB  2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1      97OX39BGVMHODLJM  2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2      041ORQM5OIHTIU6L  2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3      YT796QI18WNGZ7ZJ  2014-12-04  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4      6YLROQT27B6HRF4E  2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
# ...                 ...         ...               ...               ...
# 50012  4OMS8ZSA0UX8LHWI  2017-09-20  1TD5MROATV1NHZ4Y  E4K99D4JR9E40VE1
# 50013  RR0VKJN8V0KHNKGG  2018-03-19  22EX9VZSJKHP4AIP  E4K99D4JR9E40VE1
# 50014  STJ6QJC30WPRM93H  2017-09-21  LMX18PNGWCIMG1QW  E4K99D4JR9E40VE1
# 50015  QHEUIYNC0XQX7GDR  2018-01-28  4U0VH2TGQL30X23X  E4K99D4JR9E40VE1
# 50016  NKHFWT5I2J9LPAPG  2017-06-09  ORWFRT5TUSYGNYG7  E4K99D4JR9E40VE1
#
#                     Date of Meal                        Participants  \
# ...

# %%
#load order leads 
data_orderLeads = pd.read_csv("OrderLeads.csv")
data_orderLeads.head()
# Out:
#            Order Id        Company Id            Company Name        Date  \
# 0  80EYLOKP9E762WKG  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2017-02-18
# 1  TLEXR1HZWTUTBHPB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2015-07-30
# 2  839FKFW2LLX4LMBB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2016-05-27
# 3  97OX39BGVMHODLJM  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2018-09-27
# 4  5T4LGH4XGBWOD49Z  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2016-01-14
#
#    Order Value  Converted
# 0         4875          1
# 1         8425          0
# 2         4837          0
# 3          343          0
# 4          983          0

# %%
#convert the date to date type
data_orderLeads.Date = pd.to_datetime(data_orderLeads.Date)
print(data_orderLeads.Date)
# Out:
# 0       2017-02-18
# 1       2015-07-30
# 2       2016-05-27
# 3       2018-09-27
# 4       2016-01-14
#            ...
# 99995   2015-07-25
# 99996   2015-08-24
# 99997   2017-06-09
# 99998   2015-10-29
# 99999   2015-07-03
# Name: Date, Length: 100000, dtype: datetime64[ns]

# %%
#check if there is any null value
data_orderLeads.isnull()
# Out:
#        Order Id  Company Id  Company Name   Date  Order Value  Converted
# 0         False       False         False  False        False      False
# 1         False       False         False  False        False      False
# 2         False       False         False  False        False      False
# 3         False       False         False  False        False      False
# 4         False       False         False  False        False      False
# ...         ...         ...           ...    ...          ...        ...
# 99995     False       False         False  False        False      False
# 99996     False       False         False  False        False      False
# 99997     False       False         False  False        False      False
# 99998     False       False         False  False        False      False
# 99999     False       False         False  False        False      False
#
# [100000 rows x 6 columns]

# %%
#save the date back
data_orderLeads.to_csv("OrderLeads.csv", index=False)

# %%
#check it
pd.read_csv("OrderLeads.csv")
# Out:
#                Order Id        Company Id            Company Name        Date  \
# 0      80EYLOKP9E762WKG  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2017-02-18
# 1      TLEXR1HZWTUTBHPB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2015-07-30
# 2      839FKFW2LLX4LMBB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2016-05-27
# 3      97OX39BGVMHODLJM  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2018-09-27
# 4      5T4LGH4XGBWOD49Z  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2016-01-14
# ...                 ...               ...                     ...         ...
# 99995  4MFHIAQKH0HCACJM  E4K99D4JR9E40VE1     Fierce Productivity  2015-07-25
# 99996  K1UP23P8SIY1YION  E4K99D4JR9E40VE1     Fierce Productivity  2015-08-24
# 99997  NKHFWT5I2J9LPAPG  E4K99D4JR9E40VE1     Fierce Productivity  2017-06-09
# 99998  OF79M3H9C44UM6PO  E4K99D4JR9E40VE1     Fierce Productivity  2015-10-29
# 99999  EHN2QR78K2RX0FQ9  E4K99D4JR9E40VE1     Fierce Productivity  2015-07-03
#
#        Order Value  Converted
# ...

# %%
#load sales team
data_sales = pd.read_csv("SalesTeam.csv")
data_sales.head()
# Out:
#            Sales Rep      Sales Rep Id                    Company Name  \
# 0  Jessie Mcallister  97UNNAT790E0WM4N          Chimera-Chasing Casbah
# 1  Jessie Mcallister  97UNNAT790E0WM4N                Tangential Sheds
# 2  Jessie Mcallister  97UNNAT790E0WM4N                   Two-Mile Grab
# 3  Jessie Mcallister  97UNNAT790E0WM4N  Three-Men-And-A-Helper Congo'S
# 4  Jessie Mcallister  97UNNAT790E0WM4N        Biophysical Battleground
#
#          Company Id
# 0  LJKS5NK6788CYMUU
# 1  36MFTZOYMTAJP1RK
# 2  H3JRC7XX7WJAD4ZO
# 3  HB25MDZR0MGCQUGX
# 4  7RVA8TIVBLBXMNO4

# %%
#check if there is any null value
data_sales.isnull()
# Out:
#       Sales Rep  Sales Rep Id  Company Name  Company Id
# 0         False         False         False       False
# 1         False         False         False       False
# 2         False         False         False       False
# 3         False         False         False       False
# 4         False         False         False       False
# ...         ...           ...           ...         ...
# 4720      False         False         False       False
# 4721      False         False         False       False
# 4722      False         False         False       False
# 4723      False         False         False       False
# 4724      False         False         False       False
#
# [4725 rows x 4 columns]

# %%
#get company data only
companyData = data_sales[['Company Name','Company Id']]
companyData
# Out:
#                         Company Name        Company Id
# 0             Chimera-Chasing Casbah  LJKS5NK6788CYMUU
# 1                   Tangential Sheds  36MFTZOYMTAJP1RK
# 2                      Two-Mile Grab  H3JRC7XX7WJAD4ZO
# 3     Three-Men-And-A-Helper Congo'S  HB25MDZR0MGCQUGX
# 4           Biophysical Battleground  7RVA8TIVBLBXMNO4
# ...                              ...               ...
# 4720          Jammed-Together Stable  4JW3GG4YW52M86F5
# 4721               Laureate Barbital  R0KV9HJ7RIRRYSVG
# 4722                 Spotty Adoniram  5K17HYJQ6JG6UFU0
# 4723      Physicochemical Impatience  FC1LJXHNH2883N3Y
# 4724             Fierce Productivity  E4K99D4JR9E40VE1
#
# [4725 rows x 2 columns]

# %%
# the length of unique company name is the same with dataset
len(companyData['Company Name'].unique())
# Out:
# 4725

# %%
#load fast forrd data to get address
fastfoodData = pd.read_csv("FastFoodRestaurants.csv")
fastfoodData.head()
# Out:
#                  address                    city country  \
# 0            324 Main St                 Massena      US
# 1        530 Clinton Ave  Washington Court House      US
# 2   408 Market Square Dr               Maysville      US
# 3  6098 State Highway 37                 Massena      US
# 4        139 Columbus Rd                  Athens      US
#
#                                                 keys  latitude  longitude  \
# 0                us/ny/massena/324mainst/-1161002137  44.92130  -74.89021
# 1  us/oh/washingtoncourthouse/530clintonave/-7914...  39.53255  -83.44526
# 2       us/ky/maysville/408marketsquaredr/1051460804  38.62736  -83.79141
# 3       us/ny/massena/6098statehighway37/-1161002137  44.95008  -74.84553
# 4               us/oh/athens/139columbusrd/990890980  39.35155  -82.09728
#
#                name postalCode province  \
# 0        McDonald's      13662       NY
# 1           Wendy's      43160       OH
# 2  Frisch's Big Boy      41056       KY
# ...

# %%
#check how many unique addresses
len(fastfoodData.address.unique())
# Out:
# 9934

# %%
# take first 4725 addresses as the company's address
Locations = fastfoodData[['address', 'city','province', 'country']]
Locations = Locations.head(4725)

# %%
#take only first 4725 address as the companies's address
len(Locations)
# Out:
# 4725

# %%
#check if address duplicated
Locations['address'].duplicated
# Out:
# <bound method Series.duplicated of 0                            324 Main St
# 1                        530 Clinton Ave
# 2                   408 Market Square Dr
# 3                  6098 State Highway 37
# 4                        139 Columbus Rd
#                       ...
# 4720                         16 W 8th St
# 4721    2554 Adam Clayton Powell Jr Blvd
# 4722                      720 W 181st St
# 4723           1945 Mister Joe White Ave
# 4724                  1100 Jet Port Road
# Name: address, Length: 4725, dtype: object>

# %%
# add company names into the location dataset
Locations[['companyName','companyID']] = companyData
Locations
# Out:
#                                address                    city province  \
# 0                          324 Main St                 Massena       NY
# 1                      530 Clinton Ave  Washington Court House       OH
# 2                 408 Market Square Dr               Maysville       KY
# 3                6098 State Highway 37                 Massena       NY
# 4                      139 Columbus Rd                  Athens       OH
# ...                                ...                     ...      ...
# 4720                       16 W 8th St                New York       NY
# 4721  2554 Adam Clayton Powell Jr Blvd                New York       NY
# 4722                    720 W 181st St                New York       NY
# 4723         1945 Mister Joe White Ave            Myrtle Beach       SC
# 4724                1100 Jet Port Road            Myrtle Beach       SC
#
#      country                     companyName         companyID
# ...

# %%
# change the province to states
Locations = Locations.rename(columns= {'province':'states'})
Locations
# Out:
#                                address                    city states country  \
# 0                          324 Main St                 Massena     NY      US
# 1                      530 Clinton Ave  Washington Court House     OH      US
# 2                 408 Market Square Dr               Maysville     KY      US
# 3                6098 State Highway 37                 Massena     NY      US
# 4                      139 Columbus Rd                  Athens     OH      US
# ...                                ...                     ...    ...     ...
# 4720                       16 W 8th St                New York     NY      US
# 4721  2554 Adam Clayton Powell Jr Blvd                New York     NY      US
# 4722                    720 W 181st St                New York     NY      US
# 4723         1945 Mister Joe White Ave            Myrtle Beach     SC      US
# 4724                1100 Jet Port Road            Myrtle Beach     SC      US
#
# ...

# %%
#save the date back
Locations.to_csv("Locations.csv", index = False)

# %%
pd.read_csv("Locations.csv")
# Out:
#                                address                    city states country  \
# 0                          324 Main St                 Massena     NY      US
# 1                      530 Clinton Ave  Washington Court House     OH      US
# 2                 408 Market Square Dr               Maysville     KY      US
# 3                6098 State Highway 37                 Massena     NY      US
# 4                      139 Columbus Rd                  Athens     OH      US
# ...                                ...                     ...    ...     ...
# 4720                       16 W 8th St                New York     NY      US
# 4721  2554 Adam Clayton Powell Jr Blvd                New York     NY      US
# 4722                    720 W 181st St                New York     NY      US
# 4723         1945 Mister Joe White Ave            Myrtle Beach     SC      US
# 4724                1100 Jet Port Road            Myrtle Beach     SC      US
#
# ...
